# %% [markdown]
# # ✈️ AirFly Insights: Airline Operations Analysis
#
# ## 📌 Objective
# The objective of this project is to analyze airline flight data to uncover patterns in delays, cancellations, and operational efficiency.
#
# This analysis helps stakeholders:
# - Understand delay causes
# - Identify high-risk airlines and routes
# - Improve scheduling and performance

# %% [markdown]
# ## 📊 Dataset Overview
#
# The dataset contains airline flight records with features such as:
#
# - Airline carrier
# - Origin and destination airports
# - Departure and arrival delays
# - Cancellation status and reasons
# - Date and time details
#
# ### 🛠️ Preprocessing Done:
# - Handled missing values
# - Created new features:
#   - Month
#   - Day of Week
#   - Hour
#   - Route

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

file_path = r"C:\Users\Ankita\airfly_insights_dashboard\data\raw\Airline_Dataset_Updated_Final.xlsx"


df = pd.read_excel(file_path)

df.head()
# Out:
#    Age Airport Continent Airport Country Code               Airport Name  \
# 0   62               NAM                   US           Coldfoot Airport
# 1   62               NAM                   CA          Kugluktuk Airport
# 2   67                EU                   FR     Grenoble-Isère Airport
# 3   71               NAM                   CA  Ottawa / Gatineau Airport
# 4   21               NAM                   US            Gillespie Field
#
#   Arrival Airport     Continents   Country Name Departure Date First Name  \
# 0             CXF  North America  United States     2022-06-28     Edithe
# 1             YCO  North America         Canada     2022-12-26     Elwood
# 2             GNB         Europe         France     2022-01-18      Darby
# 3             YND  North America         Canada     2022-09-16   Dominica
# 4             SEE  North America  United States     2022-02-25        Bay
#
#   Flight Status  ... Nationality Passenger ID           Pilot Name  \
# ...

# %% [markdown]
# ## ✈️ Flight Distribution Analysis
#
# This section analyzes how flights are distributed across airlines, months, and time.
#
# ### Questions:
# - Which airline operates most flights?
# - When are flights most frequent?

# %% [markdown]
# - Flights are concentrated during peak hours (morning & evening)
# - Some airlines dominate the total flight volume
# - Monthly trends indicate seasonal demand

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## ⏱️ Delay Analysis
#
# This section explores delay patterns across airlines and time.
#
# Types of delays:
# - Carrier delay
# - Weather delay
# - NAS delay
# - Security delay

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 📌 Insight:
# - Majority of flights are on time, but delays are still significant
# - Carrier delays are the most common type
# - Delay distribution is consistent across months

# %% [markdown]
# ## 🌍 Airport & Route Analysis
#
# This section identifies:
# - Busiest airports
# - Most frequent routes
# - Delay-prone routes

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 📌 Insight:
# - Major hub airports handle the highest traffic
# - Popular routes show consistent congestion
# - Busy airports experience more delays

# %% [markdown]
# ## ❄️ Seasonal & Cancellation Trends
#
# This section analyzes cancellation trends across months and reasons.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 📊 Key Insights
#
# - Peak flight activity occurs during morning and evening
# - Carrier delays are the most frequent delay type
# - Major airports face congestion-related delays
# - Weather impacts cancellations significantly
# - Seasonal patterns influence airline performance

# %% [markdown]
# ## ✅ Conclusion
#
# This project analyzed airline operations using data visualization techniques.
#
# The analysis revealed patterns in delays, cancellations, and traffic distribution.
#
# These insights can help airlines:
# - Improve scheduling
# - Reduce delays
# - Enhance operational efficiency
