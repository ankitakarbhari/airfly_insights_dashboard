# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("cleaned_flights.csv")
df.head()

# %%
df["Route"] = df["ORIGIN_AIRPORT"] + " - " + df["DESTINATION_AIRPORT"]

# %%
top_routes = df["Route"].value_counts().head(10)

plt.figure(figsize=(10,5))
sns.barplot(x=top_routes.values, y=top_routes.index)
plt.title("Top 10 Busiest Routes")
plt.xlabel("Number of Flights")
plt.ylabel("Route")
plt.show()

# %%
top_airports = df["ORIGIN_AIRPORT"].value_counts().head(10)

plt.figure(figsize=(10,5))
sns.barplot(x=top_airports.index, y=top_airports.values)
plt.title("Top 10 Busiest Origin Airports")
plt.xlabel("Airport")
plt.ylabel("Number of Flights")
plt.show()

# %%
delay_airport = df.pivot_table(
    values="ARRIVAL_DELAY",
    index="ORIGIN_AIRPORT",
    columns="DESTINATION_AIRPORT",
    aggfunc="mean"
)

plt.figure(figsize=(12,8))
sns.heatmap(delay_airport, cmap="coolwarm")
plt.title("Average Delay Heatmap by Route")
plt.show()

# %%
monthly_flights = df.groupby("MONTH")["FLIGHT_NUMBER"].count()

plt.figure(figsize=(10,5))
sns.lineplot(x=monthly_flights.index, y=monthly_flights.values)
plt.title("Monthly Flight Trends")
plt.xlabel("Month")
plt.ylabel("Number of Flights")
plt.show()

# %%
monthly_cancel = df.groupby("MONTH")["CANCELLED"].sum()

plt.figure(figsize=(10,5))
sns.barplot(x=monthly_cancel.index, y=monthly_cancel.values)
plt.title("Monthly Cancellations")
plt.xlabel("Month")
plt.ylabel("Cancelled Flights")
plt.show()

# %%
cancel_reason = df["CANCELLATION_REASON"].value_counts()

plt.figure(figsize=(6,4))
sns.barplot(x=cancel_reason.index, y=cancel_reason.values)
plt.title("Cancellation Reasons")
plt.xlabel("Reason Code")
plt.ylabel("Count")
plt.show()

# %%
season_delay = df.groupby("MONTH")["ARRIVAL_DELAY"].mean()

plt.figure(figsize=(10,5))
sns.lineplot(x=season_delay.index, y=season_delay.values)
plt.title("Average Delay by Month")
plt.xlabel("Month")
plt.ylabel("Average Delay")
plt.show()

# %%
df.to_csv("milestone3_analysis.csv", index=False)
